# %%
import numpy as np

# %%
arr = np.array([10, 20, 30, 40, 50])

# %%
print("NumPy Array:") 
print(arr)
# Out:
# NumPy Array:
# [10 20 30 40 50]

# %%
print("\n--- Array Indexing ---") 
print("First element:", arr[0]) 
print("Third element:", arr[2]) 
print("Last element:", arr[-1])
# Out:
# --- Array Indexing ---
# First element: 10
# Third element: 30
# Last element: 50

# %%
print("\n--- Array Slicing ---") 
print("First three elements:", arr[0:3]) 
print("Elements from index 2:", arr[2:]) 
print("Last three elements:", arr[-3:])
# Out:
# --- Array Slicing ---
# First three elements: [10 20 30]
# Elements from index 2: [30 40 50]
# Last three elements: [30 40 50]

# %%
print("\n--- Basic Array Operations ---") 
print("Adding 5:", arr + 5) 
print("Subtracting 5:", arr - 5) 
print("Multiply by 2:", arr * 2) 
print("Divide by 10:", arr / 5)
# Out:
# --- Basic Array Operations ---
# Adding 5: [15 25 35 45 55]
# Subtracting 5: [ 5 15 25 35 45]
# Multiply by 2: [ 20  40  60  80 100]
# Divide by 10: [ 2.  4.  6.  8. 10.]

# %%
print("\n--- Mathematical Operations ---") 
print("Sum is:", np.sum(arr)) 
print("Mean is:", np.mean(arr)) 
print("Maximum number:", np.max(arr)) 
print("Minimum number:", np.min(arr))
# Out:
# --- Mathematical Operations ---
# Sum is: 150
# Mean is: 30.0
# Maximum number: 50
# Minimum number: 10

# %%
print("-------- Array Reshaping ------") 
reshaped_arr = arr.reshape(5, 1) 
print("Reshaped Array:") 
print(reshaped_arr)
# Out:
# -------- Array Reshaping ------
# Reshaped Array:
# [[10]
#  [20]
#  [30]
#  [40]
#  [50]]

# %%
import pandas as pd

# %%
data = { "Name": ["Asha", "Ravi", "Meera", "Karan"], 
         "Marks": [88, 72, 91, 65], 
         "Branch": ["CSE", "ECE", "CSE", "ISE"]
       }

# %%
df = pd.DataFrame(data) 
print("\n--- Pandas DataFrame ---") 
print(df)
# Out:
# --- Pandas DataFrame ---
#     Name  Marks Branch
# 0   Asha     88    CSE
# 1   Ravi     72    ECE
# 2  Meera     91    CSE
# 3  Karan     65    ISE

# %%
print("\n--- Column Indexing ---") 
print("Name Column:") 
print(df["Name"]) 
print("\nMarks Column:") 
print(df["Marks"])
# Out:
# --- Column Indexing ---
# Name Column:
# 0     Asha
# 1     Ravi
# 2    Meera
# 3    Karan
# Name: Name, dtype: str
#
# Marks Column:
# 0    88
# 1    72
# 2    91
# 3    65
# Name: Marks, dtype: int64

# %%
print("\n--- Row Indexing ---") 
print("First Row:") 
print(df.iloc[0]) 
print("\nThird Row:") 
print(df.iloc[2])
# Out:
# --- Row Indexing ---
# First Row:
# Name      Asha
# Marks       88
# Branch     CSE
# Name: 0, dtype: object
#
# Third Row:
# Name      Meera
# Marks        91
# Branch      CSE
# Name: 2, dtype: object

# %%
print("\n--- Specific Value ---") 
print("Marks of first student:", df.iloc[0, 1])
# Out:
# --- Specific Value ---
# Marks of first student: 88

# %%
print("\n--- Row Slicing ---") 
print("First two rows:") 
print(df.iloc[0:2])
# Out:
# --- Row Slicing ---
# First two rows:
#    Name  Marks Branch
# 0  Asha     88    CSE
# 1  Ravi     72    ECE

# %%
print("\n--- Row and Column Slicing ---") 
print("First three rows with Name and Marks:") 
print(df.iloc[0:3, [0, 1]])
# Out:
# --- Row and Column Slicing ---
# First three rows with Name and Marks:
#     Name  Marks
# 0   Asha     88
# 1   Ravi     72
# 2  Meera     91

# %%
print("\n--- Data Filtering ---") 
result = df[df["Marks"] > 70] 
print("Students with Marks greater than 70:") 
print(result)
# Out:
# --- Data Filtering ---
# Students with Marks greater than 70:
#     Name  Marks Branch
# 0   Asha     88    CSE
# 1   Ravi     72    ECE
# 2  Meera     91    CSE
